# %% [markdown]
# # Creating Redshift Cluster using the AWS python SDK
# ## Infrastructure-as-code

# %%
import pandas as pd
import boto3
import json
import seaborn as sns

# %% [markdown]
# # Load DWH Params from a file

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY                    = config.get('AWS','KEY')
SECRET                 = config.get('AWS','SECRET')

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

pd.DataFrame({"Param":
                  ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
              "Value":
                  [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
             })
# Out:
#                     Param       Value
# 0        DWH_CLUSTER_TYPE  multi-node
# 1           DWH_NUM_NODES           2
# 2           DWH_NODE_TYPE   dc2.large
# 3  DWH_CLUSTER_IDENTIFIER  dwhCluster
# 4                  DWH_DB         dwh
# 5             DWH_DB_USER     dwhuser
# 6         DWH_DB_PASSWORD    Passw0rd
# 7                DWH_PORT        5439
# 8       DWH_IAM_ROLE_NAME     dwhRole

# %% [markdown]
# # Create clients for IAM, EC2, S3 and Redshift
# **Note**: We are creating these resources in the the **us-west-2** region. Choose the same region in the your AWS web console to the see these resources.

# %%
import boto3

ec2 = boto3.resource('ec2',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                    )

s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                   )

iam = boto3.client('iam',aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET,
                     region_name='us-west-2'
                  )

redshift = boto3.client('redshift',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                       )

# %% [markdown]
# # Check out the sample data sources on S3

# %%
sampleDbBucket =  s3.Bucket("udacity-dend")

bucket_log = iter(sampleDbBucket.objects.filter(Prefix="log-data"))
for i in range(15):
    print(next(bucket_log))
    
bucket_song = iter(sampleDbBucket.objects.filter(Prefix="song-data"))
for i in range(15):
    print(next(bucket_song))
# Out:
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-01-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-02-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-03-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-04-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-05-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-06-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-07-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-08-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-09-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-10-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-11-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-12-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-13-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log-data/2018/11/2018-11-14-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAAK128F9318786.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAAV128F421A322.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAABD128F429CF47.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAACN128F9355673.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAEA128F935A30D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAED128E0783FAB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAEM128F93347B9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAEW128F42930C0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAFD128F92F423A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAGR128F425B14B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAHD128F42635A5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAHJ128F931194C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAHZ128E0799171.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song-data/A/A/A/TRAAAIR128F1480971.json')

# %% [markdown]
# # STEP 1: IAM ROLE
# - Create an IAM Role that makes Redshift able to access S3 bucket (ReadOnly)

# %%
from botocore.exceptions import ClientError

#1.1 Create the role, 
try:
    print("1.1 Creating a new IAM Role") 
    dwhRole = iam.create_role(
        Path='/',
        RoleName=DWH_IAM_ROLE_NAME,
        Description = "Allows Redshift clusters to call AWS services on your behalf.",
        AssumeRolePolicyDocument=json.dumps(
            {'Statement': [{'Action': 'sts:AssumeRole',
               'Effect': 'Allow',
               'Principal': {'Service': 'redshift.amazonaws.com'}}],
             'Version': '2012-10-17'})
    )    
except Exception as e:
    print(e)
    
    
print("1.2 Attaching Policy")

iam.attach_role_policy(RoleName=DWH_IAM_ROLE_NAME,
                       PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess"
                      )['ResponseMetadata']['HTTPStatusCode']

print("1.3 Get the IAM role ARN")
roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)['Role']['Arn']

print(roleArn)
# Out:
# 1.1 Creating a new IAM Role
# 1.2 Attaching Policy
# 1.3 Get the IAM role ARN
# arn:aws:iam::627838456941:role/dwhRole

# %% [markdown]
# # STEP 2:  Redshift Cluster
#
# - Create a [RedShift Cluster](https://console.aws.amazon.com/redshiftv2/home)
# - For complete arguments to `create_cluster`, see [docs](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/redshift.html#Redshift.Client.create_cluster)

# %%
try:
    response = redshift.create_cluster(        
        #HW
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        NumberOfNodes=int(DWH_NUM_NODES),

        #Identifiers & Credentials
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        
        #Roles (for s3 access)
        IamRoles=[roleArn]  
    )
except Exception as e:
    print(e)

# %% [markdown]
# ## 2.1 *Describe* the cluster to see its status
# - run this block several times until the cluster status becomes `Available`

# %%
def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', -1)
    keysToShow = ["ClusterIdentifier", "NodeType", "ClusterStatus", "MasterUsername", "DBName", "Endpoint", "NumberOfNodes", 'VpcId']
    x = [(k, v) for k,v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
# /var/folders/t5/v5_pknqn69l_gk3_3566grgr0000gn/T/ipykernel_83488/1230814843.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
# 7  NumberOfNodes
#
#                                                                                    Value
# 0  dwhcluster
# 1  dc2.large
# 2  available
# 3  dwhuser
# 4  dwh
# 5  {'Address': 'dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-0703c0a374b79d784
# 7  2

# %% [markdown]
# <h2> 2.2 Take note of the cluster <font color='red'> endpoint and role ARN </font> </h2>
# <font color='red'>DO NOT RUN THIS unless the cluster status becomes "Available". Make ure you are checking your Amazon Redshift cluster in the **us-west-2** region. </font>

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']
print("DWH_ENDPOINT :: ", DWH_ENDPOINT)
print("DWH_ROLE_ARN :: ", DWH_ROLE_ARN)
# Out:
# DWH_ENDPOINT ::  dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com
# DWH_ROLE_ARN ::  arn:aws:iam::627838456941:role/dwhRole

# %% [markdown]
# ## STEP 3: Open an incoming  TCP port to access the cluster ednpoint

# %%
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    defaultSg.authorize_ingress(
        GroupName=defaultSg.group_name,
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP',
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)
# Out:
# ec2.SecurityGroup(id='sg-0756c68b6d63db9d2')
# An error occurred (InvalidPermission.Duplicate) when calling the AuthorizeSecurityGroupIngress operation: the specified rule "peer: 0.0.0.0/0, TCP, from port: 5439, to port: 5439, ALLOW" already exists

# %% [markdown]
# # STEP 4: Make sure you can connect to the cluster

# %%
# %load_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://dwhuser:Passw0rd@dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com:5439/dwh

# %% [markdown]
# # STEP 5: Create tables and insert data

# %%
# %run create_tables.py

# %%
# %run etl.py

# %% [markdown]
# # STEP 6: Analyzing Redshift Data

# %%
# %sql SELECT * FROM songplays LIMIT 15;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com:5439/dwh
# 15 rows affected.
# [(1107, datetime.datetime(2018, 11, 1, 21, 1, 46), 8, 'free', 'SOPUDWU12A8AE4612A', 'AR0URB11187FB46C1C', 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (2366, datetime.datetime(2018, 11, 1, 21, 5, 52), 8, 'free', 'SOJBAHI12A6D4FD6B9', 'AR3HS9C1187FB48878', 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (165, datetime.datetime(2018, 11, 1, 21, 11, 13), 8, 'free', 'SOEIQUY12AF72A086A', 'ARHUC691187B9AD27F', 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (609, datetime.datetime(2018, 11, 1, 21, 55, 25), 26, 'free', 'SOFMWSD12A8C13CE54', 'ARDDMYP1187B9B8AE4', 169, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (1726, datetime.datetime(2018, 11, 2, 1, 34, 17), 83, 'free', 'SOXXRRS12A8C144735', 'AR6XT331187B9A349F', 82, 'Lubbock, TX', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (1055, datetime.datetime(2018, 11, 2, 3, 5, 57), 48, 'free', 'SOYJMYE12A8AE44C3A', 'ARMTX571187FB4AFFF', 47, 'Salinas, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (5761, datetime.datetime(2018, 11, 2, 5, 15, 41), 17, 'free', 'SOQGXVR12B0B80C04E', 'ARRH63Y1187FB47783', 118, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (5662, datetime.datetime(2018, 11, 2, 9, 26, 49), 15, 'paid', 'SOJBOJN12A81C22D69', 'ARXF40D1187B9A3FB3', 172, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (3655, datetime.datetime(2018, 11, 2, 10, 2, 20), 15, 'paid', 'SOABPFS12AB018BF15', 'AR3DTMZ1187B9A7853', 172, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (4396, datetime.datetime(2018, 11, 2, 10, 7, 43), 15, 'paid', 'SOXKFRI12A8C137A5F', 'ARWD25M1187FB4C563', 172, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (4169, datetime.datetime(2018, 11, 2, 10, 11, 24), 15, 'paid', 'SOLGVXW12A8C13CBE3', 'ARBVHDI1187FB436DF', 172, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (260, datetime.datetime(2018, 11, 2, 10, 13, 59), 15, 'paid', 'SOMSOXH12A67ADD011', 'AR1H4F51187B9946A5', 172, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (5500, datetime.datetime(2018, 11, 2, 10, 19, 18), 15, 'paid', 'SOKSFKP12B34F1EB7B', 'ARM7YQQ1187B9A84E7', 172, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (1795, datetime.datetime(2018, 11, 2, 10, 29, 6), 15, 'paid', 'SOLCKAS12A8C14242A', 'AR9ROYN1187FB4D9F1', 172, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (1435, datetime.datetime(2018, 11, 2, 10, 47, 41), 15, 'paid', 'SOLXTPE12A8C13BCE2', 'ARJXVM01187B98EED1', 172, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT COUNT(*) FROM songplays LIMIT 15;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(6500,)]

# %%
# %sql SELECT * FROM artists LIMIT 15;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com:5439/dwh
# 15 rows affected.
# [('ARQY5EG1187FB57063', 'Chuck Loeb', '', None, None),
#  ('ARQOC971187B9910FA', 'The Verve Pipe', 'Lansing, MI', 42.73383, -84.59334),
#  ('ARI0PUX1187FB3F215', 'Maxi Priest', 'Great Britain / UK', 54.31392, -2.23218),
#  ('ARDB9J71187FB4AB8B', 'James Yorkston', 'Kingsbarns, Fife, Scotland', 56.29936, -2.65978),
#  ('ARLF2G11187FB4E744', 'Los Bunkers', '', None, None),
#  ('ARMKPQP1187FB3F521', 'Webb Pierce', 'West Monroe, LA', 32.50408, -92.12783),
#  ('ARVAC3K1187FB4DED4', 'Kaiser Chiefs', 'Leeds, England', 53.79449, -1.54658),
#  ('ARLH4CH11C8A4173EC', 'Creedence Clearwater Revived', 'Lanciano Italy', 42.2306, 14.39059),
#  ('ARQAQWE1187FB49906', 'Arrah and the Ferns', '', None, None),
#  ('ARHLT3W1187FB5711F', 'Sepultura', 'Belo Horizonte, Brazil', None, None),
#  ('AR2WBR31187B9AA24E', 'Moderatto', '', None, None),
#  ('AR7UGOA1187B9B2AD0', 'Malevolent Creation', '', None, None),
#  ('ARHA3KO1187B99D51F', 'Barricada', 'MX', 23.62574, -101.95625),
#  ('ARL26PR1187FB576E5', 'Camera Obscura', 'Glasgow, Scotland', None, None),
#  ('AR5PFDG1187FB5027E', 'Yazoo', '', None, None)]

# %%
# %sql SELECT * FROM songs LIMIT 15;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com:5439/dwh
# 15 rows affected.
# [('SONHGLD12AB0188D47', 'Our Father', 'AR1S3NH1187B98C2BC', 1999, 202.4224),
#  ('SOQXJID12A8AE456CD', 'Domingo astronómico', 'ARBJ3VU1187B9B472D', 2005, 264.69832),
#  ('SOAFBKM12AB01837A7', 'Brain Dead', 'ARL14X91187FB4CF14', 1995, 94.22322),
#  ('SOINBCU12A6D4F94C0', 'Human Cannonball', 'ARV1JVD1187B9AD195', 1995, 190.48444),
#  ('SODJYTL12A8C14550E', 'Noi Nel Bene_ Noi Nel Male', 'ARHAJH611C8A4219F1', 0, 223.242),
#  ('SONWUSK12AB01837FD', "Sittin' Back Easy", 'AR1DATU1187B9A5498', 0, 222.58893),
#  ('SOFBGBL12A67020D9F', "Tuesday's Gone (Remastered Album Version)", 'ARA870V1187FB3C4B7', 0, 345.49506),
#  ('SOUVTOG12A67ADAE5C', 'Ich vermiss Dich', 'ARJEOGL1187B98E9D4', 2006, 210.72934),
#  ('SOHBTHU12A8C135B8F', 'Polish', 'ARGKBZQ1187B992BFE', 0, 250.98404),
#  ('SOCHRXB12A8AE48069', "Let's Get It Started", 'ARTDQRC1187FB4EFD4', 2004, 229.61587),
#  ('SOOTBYV12AB0186EC8', 'Gold', 'ARNULK21187FB46537', 1988, 260.91057),
#  ('SORWHWY12A6702038E', 'WKYA (drop)', 'ARXWAQQ1187B9AE954', 2001, 124.18567),
#  ('SOEOTGM12AB018AE44', 'Never Be Nothing Like Me', 'ARPVZTA1187B9A63A8', 0, 262.24281),
#  ('SOREAWH12AB017BF03', "Ain't No Secret", 'ARBTDXS11E2835CEC6', 2009, 209.34485),
#  ('SOOBRRO12A8C139153', "Tatuerarevalsen (remaster '03)", 'AROLE161187B98F7E4', 0, 181.28934)]

# %%
# %sql SELECT * FROM time LIMIT 15;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com:5439/dwh
# 15 rows affected.
# [(datetime.datetime(2018, 11, 1, 21, 1, 46), 21, 1, 44, 11, 2018, '4'),
#  (datetime.datetime(2018, 11, 1, 21, 5, 52), 21, 1, 44, 11, 2018, '4'),
#  (datetime.datetime(2018, 11, 1, 21, 11, 13), 21, 1, 44, 11, 2018, '4'),
#  (datetime.datetime(2018, 11, 1, 21, 55, 25), 21, 1, 44, 11, 2018, '4'),
#  (datetime.datetime(2018, 11, 2, 1, 34, 17), 1, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 3, 5, 57), 3, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 5, 15, 41), 5, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 9, 26, 49), 9, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 10, 2, 20), 10, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 10, 7, 43), 10, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 10, 11, 24), 10, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 10, 13, 59), 10, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 10, 19, 18), 10, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 10, 29, 6), 10, 2, 44, 11, 2018, '5'),
#  (datetime.datetime(2018, 11, 2, 10, 47, 41), 10, 2, 44, 11, 2018, '5')]

# %%
# %sql SELECT * FROM users LIMIT 15;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com:5439/dwh
# 15 rows affected.
# [('95', 'Sara', 'Johnson', 'F', 'paid'),
#  ('72', 'Hayden', 'Brock', 'F', 'paid'),
#  ('81', 'Sienna', 'Colon', 'F', 'free'),
#  ('36', 'Matthew', 'Jones', 'M', 'free'),
#  ('82', 'Avery', 'Martinez', 'F', 'paid'),
#  ('27', 'Carlos', 'Carter', 'M', 'free'),
#  ('29', 'Jacqueline', 'Lynch', 'F', 'free'),
#  ('39', 'Walter', 'Frye', 'M', 'free'),
#  ('28', 'Brantley', 'West', 'M', 'free'),
#  ('20', 'Aiden', 'Ramirez', 'M', 'paid'),
#  ('24', 'Layla', 'Griffin', 'F', 'paid'),
#  ('62', 'Connar', 'Moreno', 'M', 'free'),
#  ('35', 'Molly', 'Taylor', 'F', 'free'),
#  ('78', 'Chloe', 'Roth', 'F', 'free'),
#  ('77', 'Magdalene', 'Herman', 'F', 'free')]

# %%
user_gender_count = pd.read_sql_query("""
SELECT gender, COUNT(gender) as gender_count
FROM users
GROUP BY 1""", con= conn_string)

sns.barplot(data= user_gender_count, x = 'gender', y = 'gender_count');

# %% [markdown]
# # STEP 7: Clean up your resources
#
# <b><font color='red'>DO NOT RUN THIS UNLESS YOU ARE SURE <br/>
#     We will be using these resources in the next exercises</span></b>

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
redshift.delete_cluster( ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,  SkipFinalClusterSnapshot=True)
#### CAREFUL!!
# Out:
# {'Cluster': {'ClusterIdentifier': 'dwhcluster',
#   'NodeType': 'dc2.large',
#   'ClusterStatus': 'deleting',
#   'ClusterAvailabilityStatus': 'Modifying',
#   'MasterUsername': 'dwhuser',
#   'DBName': 'dwh',
#   'Endpoint': {'Address': 'dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com',
#    'Port': 5439},
#   'ClusterCreateTime': datetime.datetime(2022, 7, 9, 3, 52, 34, 881000, tzinfo=tzutc()),
#   'AutomatedSnapshotRetentionPeriod': 1,
#   'ManualSnapshotRetentionPeriod': -1,
#   'ClusterSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0756c68b6d63db9d2',
#     'Status': 'active'}],
#   'ClusterParameterGroups': [{'ParameterGroupName': 'default.redshift-1.0',
#     'ParameterApplyStatus': 'in-sync'}],
#   'ClusterSubnetGroupName': 'default',
#   'VpcId': 'vpc-0703c0a374b79d784',
#   'AvailabilityZone': 'us-west-2c',
#   'PreferredMaintenanceWindow': 'mon:11:30-mon:12:00',
#   'PendingModifiedValues': {},
#   'ClusterVersion': '1.0',
#   'AllowVersionUpgrade': True,
#   'NumberOfNodes': 2,
#   'PubliclyAccessible': True,
#   'Encrypted': False,
#   'Tags': [],
#   'EnhancedVpcRouting': False,
#   'IamRoles': [{'IamRoleArn': 'arn:aws:iam::627838456941:role/dwhRole',
#     'ApplyStatus': 'in-sync'}],
#   'MaintenanceTrackName': 'current',
#   'DeferredMaintenanceWindows': [],
#   'NextMaintenanceWindowStartTime': datetime.datetime(2022, 7, 11, 11, 30, tzinfo=tzutc()),
#   'TotalStorageCapacityInMegaBytes': 800000,
#   'AquaConfiguration': {'AquaStatus': 'disabled',
#    'AquaConfigurationStatus': 'auto'}},
#  'ResponseMetadata': {'RequestId': 'f12159bf-7f62-4649-99c9-b92409bd3df7',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f12159bf-7f62-4649-99c9-b92409bd3df7',
#    'content-type': 'text/xml',
#    'content-length': '2702',
#    'vary': 'accept-encoding',
#    'date': 'Sat, 09 Jul 2022 08:08:05 GMT'},
#   'RetryAttempts': 0}}

# %%
myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
# /var/folders/t5/v5_pknqn69l_gk3_3566grgr0000gn/T/ipykernel_83488/1230814843.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
# 7  NumberOfNodes
#
#                                                                                    Value
# 0  dwhcluster
# 1  dc2.large
# 2  deleting
# 3  dwhuser
# 4  dwh
# 5  {'Address': 'dwhcluster.cow6i5ovvfwz.us-west-2.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-0703c0a374b79d784
# 7  2

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
iam.detach_role_policy(RoleName=DWH_IAM_ROLE_NAME, PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess")
iam.delete_role(RoleName=DWH_IAM_ROLE_NAME)
#### CAREFUL!!
# Out:
# {'ResponseMetadata': {'RequestId': '72e61604-937b-422f-99dc-835b76a58c35',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '72e61604-937b-422f-99dc-835b76a58c35',
#    'content-type': 'text/xml',
#    'content-length': '200',
#    'date': 'Sat, 09 Jul 2022 08:08:12 GMT'},
#   'RetryAttempts': 0}}
